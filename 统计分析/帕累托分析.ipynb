# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame(np.random.rand(10),index=list('abcdefghij'))
data = data[0].sort_values(ascending=False)

# %%
p = data.cumsum()/data.sum()
p
# Out:
# i    0.171388
# c    0.331839
# a    0.491325
# g    0.626449
# h    0.755666
# e    0.839101
# b    0.922221
# d    0.972976
# f    0.995217
# j    1.000000
# Name: 0, dtype: float64

# %%
data.plot(kind='bar')

# %%
data = [11,22,11,33,23,24,26,43,22,22,33,45,34,56,11,22,11,33,23,24,26,43,22,22,33,45,34,56,23,34,23,25,22,26,27,23,24]
data = pd.DataFrame(data,columns=['values'])
u = np.mean(data)
std = np.std(data)
u,std
# Out:
# (values    28.027027
#  dtype: float64, values    10.913633
#  dtype: float64)

# %%
from scipy import stats
stats.kstest(data['values'],'norm',(u,std))
# Out:
# KstestResult(statistic=0.19529473766970235, pvalue=0.10355268960227426)

# %%
data.plot(kind = 'kde')
data.plot(kind ='bar')
